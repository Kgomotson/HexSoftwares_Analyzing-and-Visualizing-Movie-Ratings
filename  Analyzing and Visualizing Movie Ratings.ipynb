# %%
import seaborn as sb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics 
movie_dataset = pd.read_csv("C:/Users/Motso/Documents/HEX DATA SCIENCE INTERNSHIP TASKS/imdb_top_1000.csv")

# %%
movie_dataset.head(13)
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
#
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# ...

# %%
movie_dataset.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
print(movie_dataset.isnull().values.any())
# Out:
# True

# %%
movie_dataset.nunique()
# Out:
# Poster_Link      1000
# Series_Title      999
# Released_Year     100
# Certificate        16
# Runtime           140
# Genre             202
# IMDB_Rating        17
# Overview         1000
# Meta_score         63
# Director          548
# Star1             660
# Star2             841
# Star3             891
# Star4             939
# No_of_Votes       999
# Gross             823
# dtype: int64

# %%
movie_dataset.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
movie_dataset = movie_dataset.dropna(axis = 0)

# %%
movie_dataset.isnull().sum()
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
print(movie_dataset['Series_Title'])
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               The Dark Knight
# 3        The Godfather: Part II
# 4                  12 Angry Men
#                  ...
# 990                Giù la testa
# 991              Kelly's Heroes
# 992             The Jungle Book
# 994          A Hard Day's Night
# 997       From Here to Eternity
# Name: Series_Title, Length: 714, dtype: object

# %%
movie_dataset.duplicated().sum()
# Out:
# 0

# %%
movie_dataset.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
movie_dataset.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count   714.000000  714.000000  7.140000e+02
# mean      7.937115   77.158263  3.561348e+05
# std       0.293278   12.401144  3.539011e+05
# min       7.600000   28.000000  2.522900e+04
# 25%       7.700000   70.000000  9.600975e+04
# 50%       7.900000   78.000000  2.366025e+05
# 75%       8.100000   86.000000  5.077922e+05
# max       9.300000  100.000000  2.343110e+06

# %%
movie_dataset.groupby(['IMDB_Rating','Series_Title'])['IMDB_Rating','Series_Title'].agg(['mean','count'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 movie_dataset.groupby(['IMDB_Rating','Series_Title'])['IMDB_Rating','Series_Title'].agg(['mean','count'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
#    1951 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.

# %%
top15_movies= movie_ratings.nlargest(15, 'IMDB_Rating')[['Series_Title','IMDB_Rating']].set_index('Series_Title')
print(top15_movies)

# %%
top15_genres =  movie_ratings.nlargest(15, 'IMDB_Rating')[['Genre','IMDB_Rating']].set_index('Genre')
print(top15_genres)
# Out:
#                            IMDB_Rating
# Genre
# Drama                              9.3
# Crime, Drama                       9.2
# Action, Crime, Drama               9.0
# Crime, Drama                       9.0
# Crime, Drama                       9.0
# Action, Adventure, Drama           8.9
# Crime, Drama                       8.9
# Biography, Drama, History          8.9
# Action, Adventure, Sci-Fi          8.8
# Drama                              8.8
# Action, Adventure, Drama           8.8
# Drama, Romance                     8.8
# Western                            8.8
# Action, Adventure, Drama           8.7
# Action, Sci-Fi                     8.7

# %%
top15_genres.plot(kind = 'bar')
plt.show()

# %%
top15_genres.groupby(['Genre','IMDB_Rating'])['IMDB_Rating'].count()
# Out:
# Genre                      IMDB_Rating
# Action, Adventure, Drama   8.7            1
#                            8.8            1
#                            8.9            1
# Action, Adventure, Sci-Fi  8.8            1
# Action, Crime, Drama       9.0            1
# Action, Sci-Fi             8.7            1
# Biography, Drama, History  8.9            1
# Crime, Drama               8.9            1
#                            9.0            2
#                            9.2            1
# Drama                      8.8            1
#                            9.3            1
# Drama, Romance             8.8            1
# Western                    8.8            1
# Name: IMDB_Rating, dtype: int64

# %%
sb.relplot(x =

# %%
agg_dataset = movie_ratings.groupby(['Genre','IMDB_Rating'])['IMDB_Rating'].max()
print(agg_dataset)
# Out:
# Genre                         IMDB_Rating
# Action, Adventure             7.7            7.7
#                               8.2            8.2
#                               8.4            8.4
# Action, Adventure, Biography  7.9            7.9
# Action, Adventure, Comedy     7.6            7.6
#                                             ...
# Thriller                      7.8            7.8
# Western                       7.8            7.8
#                               8.3            8.3
#                               8.5            8.5
#                               8.8            8.8
# Name: IMDB_Rating, Length: 590, dtype: float64

# %%
median = np.median(agg_dataset)
mean = np.mean(agg_dataset)
mode = statistics.mode(agg_dataset)
